# %% [markdown]
# <a href="https://colab.research.google.com/github/arifanf/MSIB21/blob/main/D16_Introduction_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day16 - Senin, 13 September 2021

# %% [markdown]
# #### print string dan variable

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Halo Dunia")
print("Riset Bahasa Python")
# Out:
# Halo Dunia
# Riset Bahasa Python

# %%
bilangan1 = 20
bilangan2 = 10
print(bilangan1 - bilangan2)
# Out:
# 10

# %% [markdown]
# #### List

# %%
contoh_list = ['Dewi', 'Budi', 'Cici', 'Linda', 'Cici']
print(contoh_list)
contoh_set = {'Dewi', 'Budi', 'Cici', 'Linda', 'Cici'}
print(contoh_set)
contoh_frozen_set = ({'Dewi', 'Budi', 'Cici', 'Linda', 'Cici'})
print(contoh_frozen_set)
# Out:
# ['Dewi', 'Budi', 'Cici', 'Linda', 'Cici']
# {'Linda', 'Cici', 'Budi', 'Dewi'}
# {'Linda', 'Cici', 'Budi', 'Dewi'}

# %%
contoh_list = [1, 'dua', 3, 4.0, 5]
print(contoh_list[0])
print(contoh_list[3])
contoh_list = [1, 'dua', 3, 4.0, 5]
contoh_list[3] = 'empat'
print(contoh_list[3])
# Out:
# 1
# 4.0
# empat

# %%
contoh_list = [1, 'dua', 3, 4.0, 5]
print(contoh_list[0])
print(contoh_list[3])
contoh_list = [1, 'dua', 3, 4.0, 5]
contoh_list[3] = 'empat'
print(contoh_list[3])
# Out:
# 1
# 4.0
# empat

# %% [markdown]
# #### Dictionary

# %%
person = {'nama': 'Arifa', 'pekerjaan': 'Programmer'}
print(person['nama'])
print(person['pekerjaan'])
# Out:
# Arifa
# Programmer
